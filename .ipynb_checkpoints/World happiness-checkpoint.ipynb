# %%
import pandas as pd
import numpy as np

df2015 = pd.read_csv('data/2015.csv')
df2016 = pd.read_csv('data/2016.csv')
df2017 = pd.read_csv('data/2017.csv')
df2018 = pd.read_csv('data/2018.csv')
df2019 = pd.read_csv('data/2019.csv')

# %%
df2015['Year'] = 2015
df2016['Year'] = 2016
df2017['Year'] = 2017
df2018['Year'] = 2018
df2019['Year'] = 2019

# %%
# Update column names
df2015 = df2015.rename(columns={"": ""})
df2016 = df2016.rename(columns={"": ""})
df2017 = df2017.rename(columns={"Happiness.Score": "Happiness Score", "Happiness.Rank": "Happiness Rank"})
df2018 = df2018.rename(columns={"Score": "Happiness Score", "Overall rank": "Happiness Rank"})
df2019 = df2019.rename(columns={"Score": "Happiness Score", "Overall rank": "Happiness Rank"})
df2019
# Out:
#      Happiness Rank         Country or region  Happiness Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 0             1.340           1.587                    0.986
# 1             1.383           1.573                    0.996
# ...
